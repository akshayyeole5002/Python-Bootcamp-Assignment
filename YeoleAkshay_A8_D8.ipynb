# %% [markdown]
# **Q.1**

# %%
a=500
if  a<=500:
  print("You can buy the courses")
else:
  print("You cannot buy the courses")
# Out:
# You can buy the courses

# %% [markdown]
# **Q.2.**

# %%
a=int(input())
b=int(input())
c=a+b
d=c%2
if d==0:
  print("sum is even")
else:
  print(c)
# Out:
# 4
# 4
# sum is even

# %% [markdown]
# **Q.3.**
# Indentation are used to denote a block of code.basically,every time you end a line with a colon(:)the following line needs to be indentation.

# %% [markdown]
# **Q.4.**

# %%
Year=int(input())
if((Year % 400 == 0) or
   (Year % 100 !=0) and
   (Year % 4 == 0)):
   print("Given year is leap  year")
else:
  print("Not a leap year")
# Out:
# 2030
# Not a leap year

# %% [markdown]
# **Q.5.**

# %%
percentage=int(input())
if percentage<35:
  print("failed")
else:
  print("passed")
# Out:
# 79
# passed
