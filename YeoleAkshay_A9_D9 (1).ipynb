# %% [markdown]
# **Q.1.**

# %%
a=int(input())
if a%2==0:
  print("Given number is even")
else:
  print("Given number is odd")
# Out:
# 103
# Given number is odd

# %% [markdown]
# **Q.2.**

# %%
a=int(input())
if a<=12:
  print("You are child")
elif 12<=a<=19:
  print("You are Teenager")
else:
  print("You are Adult")
# Out:
# 19
# You are Teenager

# %% [markdown]
# **Q.3.**

# %%
Temp=int(input())
if Temp<=20:
  print("Wear Jacket")
elif 20<=Temp<=35:
  print("Enjoy the outdoors")
else:
  print("Stay Hydrated")
# Out:
# 20
# Wear Jacket

# %% [markdown]
# **Q.4.**

# %%
Light=str(input())
if Light=='red':
  print("STOP!")
elif Light=='yellow':
  print("Prepare to stop")
elif Light=='green':
  print("Go!")
else:
  print("Invalid input")
# Out:
# Green
# Invalid input

# %% [markdown]
# **Q.5.**

# %%
print("Enter amount in $")
a=int(input())
if a<=50:
  print("5% Discounted of price=",a-(a*0.15))
elif 50<a<100:
  print("10% Discounted of price=",a-(a*0.10))
else :
  print("15% Discounted of price=",a-(a*0.15))
# Out:
# Enter amount in $
# 100
# 15% Discounted of price= 85.0
